# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# reading csv files
df =  pd.read_csv('processed.cleveland.data', sep=",")
df.columns = ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol', 'fasting_blood_sugar', 'rest_ecg', 'max_heart_rate',
       'exercise_induced_angina', 'st_depression', 'st_slope', 'num_major_vessels', 'thalassemia', 'occurrence']
df['occurrence'] = np.where(df['occurrence'] !=0,1, df['occurrence'])

df['sex'] = df['sex'].astype('int')
df['chest_pain_type'] = df['chest_pain_type'].astype('int')
df['fasting_blood_sugar'] = df['fasting_blood_sugar'].astype('int')
df['rest_ecg'] = df['rest_ecg'].astype('int')
df['exercise_induced_angina'] = df['exercise_induced_angina'].astype('int')
df['st_slope'] = df['st_slope'].astype('int')
#df['thalassemia'] = df['thalassemia'].astype('int')

df.dtypes
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [7], in <cell line: 4>()
#       1 import pandas as pd
#       3 # reading csv files
# ----> 4 df =  pd.read_csv('processed.cleveland.data', sep=",")
#       5 df.columns = ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol', 'fasting_blood_sugar', 'rest_ecg', 'max_heart_rate',
#       6        'exercise_induced_angina', 'st_depression', 'st_slope', 'num_major_vessels', 'thalassemia', 'occurrence']
#       7 df['occurrence'] = np.where(df['occurrence'] !=0,1, df['occurrence'])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...

# %%
df.head()
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df.head()
#       2 df.info()
#
# NameError: name 'df' is not defined

# %%
df["occurrence"].value_counts()
df["age"].min()
df["age"].max()
# Out:
# 77.0

# %%
sns.countplot(x="occurrence", data=df)
plt.show()
df["sex"].value_counts()
sns.countplot(x="sex", data=df)
plt.show()

# %%
sns.countplot(x="age", data=df)
plt.show()
pd.crosstab(df.age,df.occurrence).plot(kind="bar",figsize=(20,6))
plt.title('Heart Disease Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.savefig('heartDiseaseAndAges.png')
plt.show()

# %%
pd.crosstab(df.sex,df.occurrence).plot(kind="bar",figsize=(15,6))
plt.title('Heart Disease Frequency for Sex')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.xticks(rotation=0)
plt.legend(["Haven't Disease", "Have Disease"])
plt.ylabel('count')
plt.show()

# %%
def draw_histograms(dataframe, features, rows, cols):
    fig=plt.figure(figsize=(20,20))
    for i, feature in enumerate(features):
        ax=fig.add_subplot(rows,cols,i+1)
        dataframe[feature].hist(bins=20,ax=ax,facecolor='midnightblue')
        ax.set_title(feature+" Distribution",color='DarkRed')
        
    fig.tight_layout()  
    plt.show()
draw_histograms(df,df.columns,6,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 10>()
#       8     fig.tight_layout()
#       9     plt.show()
# ---> 10 draw_histograms(df,df.columns,6,3)
#
# NameError: name 'df' is not defined
